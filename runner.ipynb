# %%
import cv2
import pathlib as path
import sys
path_root = path.Path.cwd() # Assuming the script is run from the root directory

# %%
def mp4_to_avi(input_file, output_file):
    print(f"Getting ready for convering {input_file} to {output_file}")
    # Open the input video
    input_file = str(input_file)
    output_file = str(output_file)

    cap = cv2.VideoCapture(input_file)
    
    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # Define codec and create VideoWriter
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
    
    # Process each frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        out.write(frame)
    
    # Release resources
    cap.release()
    out.release()

    print(f"Converted {input_file} to {output_file}")

input_file = path_root / 'input/raw/subject1/video1142643710.mp4'
output_file = path_root / 'input/raw/subject1/video1142643710.avi'

mp4_to_avi(input_file, output_file)
# Out:
# Getting ready for convering /home/macie/GitHub/rPPG-Toolbox/input/raw/subject1/video1142643710.mp4 to /home/macie/GitHub/rPPG-Toolbox/input/raw/subject1/video1142643710.avi
# Converted /home/macie/GitHub/rPPG-Toolbox/input/raw/subject1/video1142643710.mp4 to /home/macie/GitHub/rPPG-Toolbox/input/raw/subject1/video1142643710.avi
# [ERROR:0] global /tmp/pip-req-build-13uokl4r/opencv/modules/videoio/src/cap.cpp (160) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.5.2) /tmp/pip-req-build-13uokl4r/opencv/modules/videoio/src/cap_images.cpp:267: error: (-215:Assertion failed) number < max_number in function 'icvExtractPattern'
#
#
# [ERROR:0] global /tmp/pip-req-build-13uokl4r/opencv/modules/videoio/src/cap.cpp (587) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.5.2) /tmp/pip-req-build-13uokl4r/opencv/modules/videoio/src/cap_images.cpp:267: error: (-215:Assertion failed) number < max_number in function 'icvExtractPattern'

# %%
# !TORCH_USE_CUDA_DSA=1
# !python main.py --config_file ./configs/infer_configs/mkos-test-PURE_UBFC-rPPG_PHYSMAMBA_BASIC.yaml
# Out:
# => Merging a config file from ./configs/infer_configs/mkos-test-PURE_UBFC-rPPG_PHYSMAMBA_BASIC.yaml
# Configuration:
# BASE: ['']
# DEVICE: cuda:0
# INFERENCE:
#   BATCH_SIZE: 4
#   EVALUATION_METHOD: FFT
#   EVALUATION_WINDOW:
#     USE_SMALLER_WINDOW: False
#     WINDOW_SIZE: 10
#   MODEL_PATH: final_model_release/PURE_PhysMamba_DiffNormalized.pth
# LOG:
#   PATH: runs/inference_experiment
# MODEL:
#   BIGSMALL:
#     FRAME_DEPTH: 3
#   DROP_RATE: 0.0
#   EFFICIENTPHYS:
#     FRAME_DEPTH: 10
#   FactorizePhys:
#     CHANNELS: 3
#     FRAME_NUM: 160
#     MD_FSAM: False
#     MD_INFERENCE: True
#     MD_R: 1
#     MD_RESIDUAL: True
#     MD_S: 1
#     MD_STEPS: 4
#     MD_TRANSFORM: T_KAB
#     MD_TYPE: NMF
#     TYPE: Standard
#   MODEL_DIR: runs/inference_experiment/_SizeW128_SizeH128_ClipLength180_DataType_DataAugNone_LabelType_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/PreTrainedModels
#   NAME: PhysMamba
#   PHYSFORMER:
# ...

# %%
# !python main.py --config_file ./configs/infer_configs/mkos-test-PURE_UBFC-rPPG_PHYSMAMBA_BASIC.yaml
# Out:
# => Merging a config file from ./configs/infer_configs/mkos-test-PURE_UBFC-rPPG_PHYSMAMBA_BASIC.yaml
# Configuration:
# BASE: ['']
# DEVICE: cuda:0
# INFERENCE:
#   BATCH_SIZE: 4
#   EVALUATION_METHOD: FFT
#   EVALUATION_WINDOW:
#     USE_SMALLER_WINDOW: False
#     WINDOW_SIZE: 10
#   MODEL_PATH: final_model_release/PURE_PhysMamba_DiffNormalized.pth
# LOG:
#   PATH: runs/inference_experiment
# MODEL:
#   BIGSMALL:
#     FRAME_DEPTH: 3
#   DROP_RATE: 0.0
#   EFFICIENTPHYS:
#     FRAME_DEPTH: 10
#   FactorizePhys:
#     CHANNELS: 3
#     FRAME_NUM: 160
#     MD_FSAM: False
#     MD_INFERENCE: True
#     MD_R: 1
#     MD_RESIDUAL: True
#     MD_S: 1
#     MD_STEPS: 4
#     MD_TRANSFORM: T_KAB
#     MD_TYPE: NMF
#     TYPE: Standard
#   MODEL_DIR: runs/inference_experiment/_SizeW128_SizeH128_ClipLength180_DataType_DataAugNone_LabelType_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/PreTrainedModels
#   NAME: PhysMamba
#   PHYSFORMER:
# ...
